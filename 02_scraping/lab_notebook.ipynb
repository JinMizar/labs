# %% [markdown]
# # Web Scraping
#
# Last time, we looked at REST API's as a source of data. You can get lots of very high quality data this way.
#
# Some data is available online, but not through an API. When this is the case, some times you can simply copy and paste the data into a .csv file and go on with your life. But if there are many records to parse and combine into a dataset, that might be impossible. Can we automate the collection of data from online sources?
#
# This is called web scraping. Broadly speaking: Web scraping is legal, but what you plan to do with the results of your scraping might not be. In general, most sites do not want you to scrape them at this point, but there is not really a way to stop you if you are sufficiently motivated. Be careful to use server resources respectfully (not too many requests per unit time), think seriously about privacy concerns, and be careful who you share your work with.

# %% [markdown]
# We'll be scraping data about used cars in Charlottesville from Craigslist. This will give us a chance to put those wrangling, EDA, and visualization skills to work.
#
# We'll use the `requests` package, as we did with API's, but will be getting the kinds of web pages you see everyday. Again, we'll use a header with a user-agent that masks our true identity so that we're not rejected by the server. This particular url points to the car listings for Craigslist in Charlottesville.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import requests # Page requests

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'}
url = 'https://charlottesville.craigslist.org/search/mca#search=1~gallery~0~0'
raw = requests.get(url,headers=header) # Get page

# %% [markdown]
# Now that we have that particular page available locally, we want to **parse** it and get results from it. To do that, we can use a package called `beautifulSoup` or `bs4`.
#
# What does `beautifulSoup` do for us? Let's go to the web page of interest. You probably see something like this:
#
# ![Listings](craigslist.png "Craigslist")
#
# But if you "view page source" -- which is CTRL+U -- in Chrome, you see what the computer sees:
#
# ![Listings](craigslist_source.png "Craigslist")
#
# Since your web browser needs lots of instructions about how to render the text, pictures, and other content on your web page, there are a lot of clues about where the data live and how to extricate them from a page. These clues are called **tags**. If you wander the source for the search page on cars, you see a particular `class = "cl-static-search-result"` term appear attached to each listing:
#
# ![Listings](listing.png "Craigslist")
#
# This structure can be exploited to search the page for information. This kind of detective work -- looking at the page source, finding the interesting tages, and then searching the page with `beautifulSoup` -- is the basic job of web scraping.

# %% [markdown]
# ## 1. Pick something else on Craigslist: Musical instruments, roommates, antiques, etc. Look at the search page and its source code. Record which fields/data you would like to gather, and what kinds of EDA you'd do with it.

# %% [markdown]
# The following code chunk takes the raw content from `requests` and turns it into a beautifulSoup object, which can search the page and return results for us:

# %%
from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings

# %% [markdown]
# Why is the argument `class_` and not just `class`? The word `class` is a reserved keyword for Python, and cannot be used by anyone else, similar to `True` and `False`. But since we want the `class = "cl-static-search-result"` terms, we need to use the `class_` argument to the `.find_all` method.
#
# The `.find_all` function dredges the entire page and finds all the instances of `class = "cl-static-search-result"`, resulting in a list of entries. We can then parse the entries.
#
# For each listing, we'll use the `.find` method to search within the listing record for specific information. To get the information we want, we can then use `.get_text()`.
#
# In the code below, two more things happen.
#
# First, I would like to get the brand of the car from the post title, if possible. To do this, I split the title into words using `title.split()`, and then I use a list comprehension to look over every word in the title and check whether it appears in the `brands` list.
#
# Second, I would like to get the year the car was built, so I can determine the vehicle's age. To do this, I use a thing called **regular expressions** that provides a language for expressing patterns. Do I remember how to do this off the top of my head? No, I read a few pages in a book and looked on StackOverflow for answers. Roughly, in order to express the idea "any year starting with 20xx," you can write `20[0-9][0-9]`, and for "any year starting with 19xx," you can write `19[0-9][0-9]`. The `[0-9]`'s act as wildcards for any digit. This allows me to use the `re` package to find any instances of year-like numbers in the title text, using `re.search(r'20[0-9][0-9]|19[0-9][0-9]', title )`.
#
# This is all nested in a for-loop over the listings, and the data is appended to a list.

# %%
import re # Regular expressions

data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']

    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)

    data.append({'title':title,'price':price,'year':year,'link':link})

# %% [markdown]
# I was also trying to scape the mileage of the motorcycle, but I have tried serveral methods and search online while still getting output of nan for the mileage field.

# %% [markdown]
# ## 2. Get your search results of interest and extract data from them, using code similar to what's above.

# %% [markdown]
# With the data scraped from Craigslist, we can put it in a dataframe and wrangle it. Of course, price and year come in as text, not numbers, and need to be typecast/coerced:

# %%
## Wrangle the data
df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['year'] = pd.to_numeric(df['year'],errors='coerce')
df['age'] = 2025-df['year']
df = df[(df['price'] > 0) & (df['age'] > 0)]
print(df.shape)
df.to_csv('craigslist_cville_cars.csv') # Save data in case of a disaster
df.head()
# Out:
# (13, 5)
#                            title  price    year  \
# 1  1991 harley heritage softtail   5300  1991.0
# 2         2003 sv650s track bike   1500  2003.0
# 3         2017 indian roadmaster  14995  2017.0
# 4             2005 yamaha v-star   3750  2005.0
# 5          2021 ktm390 adventure   5500  2021.0
#
#                                                 link   age
# 1  https://charlottesville.craigslist.org/mcy/d/l...  34.0
# 2  https://charlottesville.craigslist.org/mcy/d/w...  22.0
# 3  https://charlottesville.craigslist.org/mcy/d/c...   8.0
# 4  https://charlottesville.craigslist.org/mcy/d/s...  20.0
# 5  https://charlottesville.craigslist.org/mcy/d/c...   4.0

# %% [markdown]
# With the data in and wrangled, we can now do EDA:

# %%
# EDA for price and age:
print(df['price'].describe())
df['price'].hist(grid=False)
plt.show()
print(df['age'].describe())
df['age'].hist(grid=False)
plt.show()
# Out:
# count       13.000000
# mean      6734.230769
# std       5504.386829
# min       1500.000000
# 25%       3750.000000
# 50%       5500.000000
# 75%       6500.000000
# max      21500.000000
# Name: price, dtype: float64
# count    13.000000
# mean     15.384615
# std       8.461072
# min       4.000000
# 25%       8.000000
# 50%      14.000000
# 75%      22.000000
# max      34.000000
# Name: age, dtype: float64

# %%
# Price by age:
df.loc[:,['price','age']].groupby('age').describe()
# Out:
#      price                                                                   \
#      count          mean          std      min       25%      50%       75%
# age
# 4.0    1.0   5500.000000          NaN   5500.0   5500.00   5500.0   5500.00
# 7.0    1.0   4750.000000          NaN   4750.0   4750.00   4750.0   4750.00
# 8.0    2.0  10747.500000  6006.872106   6500.0   8623.75  10747.5  12871.25
# 9.0    1.0  21500.000000          NaN  21500.0  21500.00  21500.0  21500.00
# 13.0   1.0   2500.000000          NaN   2500.0   2500.00   2500.0   2500.00
# 14.0   1.0   6000.000000          NaN   6000.0   6000.00   6000.0   6000.00
# 17.0   1.0   5750.000000          NaN   5750.0   5750.00   5750.0   5750.00
# 20.0   1.0   3750.000000          NaN   3750.0   3750.00   3750.0   3750.00
# 22.0   3.0   3666.666667  2565.800720   1500.0   2250.00   3000.0   4750.00
# 34.0   1.0   5300.000000          NaN   5300.0   5300.00   5300.0   5300.00
#
#
#           max
# age
# 4.0    5500.0
# 7.0    4750.0
# 8.0   14995.0
# 9.0   21500.0
# 13.0   2500.0
# 14.0   6000.0
# 17.0   5750.0
# 20.0   3750.0
# 22.0   6500.0
# 34.0   5300.0

# %% [markdown]
# There are some NaN for some groups I think that is because there is only one entry for that particular age.

# %%
# Price by motocycle:
df.loc[:,['price','title']].groupby('title').describe()
# Out:
#                                        price                                 \
#                                        count     mean std      min      25%
# title
# 1991 harley heritage softtail            1.0   5300.0 NaN   5300.0   5300.0
# 2003 bmw r1200cl                         1.0   3000.0 NaN   3000.0   3000.0
# 2003 harley fatboy                       1.0   6500.0 NaN   6500.0   6500.0
# 2003 sv650s track bike                   1.0   1500.0 NaN   1500.0   1500.0
# 2005 yamaha v-star                       1.0   3750.0 NaN   3750.0   3750.0
# 2008 bmw r1200 - for sale                1.0   5750.0 NaN   5750.0   5750.0
# 2011 bmw r1200rt with new tires          1.0   6000.0 NaN   6000.0   6000.0
# 2012 suzuki burgman 400                  1.0   2500.0 NaN   2500.0   2500.0
# 2016 harley-davidson trike freewheeler   1.0  21500.0 NaN  21500.0  21500.0
# 2017 ducati scrambler 800                1.0   6500.0 NaN   6500.0   6500.0
# 2017 indian roadmaster                   1.0  14995.0 NaN  14995.0  14995.0
# 2018 vespa gts super abs                 1.0   4750.0 NaN   4750.0   4750.0
# 2021 ktm390 adventure                    1.0   5500.0 NaN   5500.0   5500.0
#
#
#                                             50%      75%      max
# title
# 1991 harley heritage softtail            5300.0   5300.0   5300.0
# 2003 bmw r1200cl                         3000.0   3000.0   3000.0
# 2003 harley fatboy                       6500.0   6500.0   6500.0
# 2003 sv650s track bike                   1500.0   1500.0   1500.0
# 2005 yamaha v-star                       3750.0   3750.0   3750.0
# 2008 bmw r1200 - for sale                5750.0   5750.0   5750.0
# 2011 bmw r1200rt with new tires          6000.0   6000.0   6000.0
# 2012 suzuki burgman 400                  2500.0   2500.0   2500.0
# 2016 harley-davidson trike freewheeler  21500.0  21500.0  21500.0
# 2017 ducati scrambler 800                6500.0   6500.0   6500.0
# 2017 indian roadmaster                  14995.0  14995.0  14995.0
# 2018 vespa gts super abs                 4750.0   4750.0   4750.0
# 2021 ktm390 adventure                    5500.0   5500.0   5500.0

# %%
ax = sns.scatterplot(data=df, x='age', y='price',hue='title')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
df['log_price'] = np.log(df['price'])
df['log_age'] = np.log(df['age'])

ax = sns.scatterplot(data=df, x='log_age', y='log_price',hue='title')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

print(df.loc[:,['log_price','log_age']].cov())
print(df.loc[:,['log_price','log_age']].corr())
# Out:
#            log_price   log_age
# log_price   0.480210 -0.172464
# log_age    -0.172464  0.366197
#            log_price   log_age
# log_price   1.000000 -0.411269
# log_age    -0.411269  1.000000

# %%
sns.jointplot(data=df, x='log_age', y='log_price',kind='hex')

# %% [markdown]
# ## 3. Wrangle your data, do some EDA, and make some plots. Try to find some interesting relationships or stories to tell about your data.

# %% [markdown]
# The final thing we want to do is go from scraping a single page to crawling around.
#
# The idea here is that every web page is connected to some other page. By extracting links as we move from page to page, we can create a web crawler that wanders around for us, gathering information of interest.
#
# In this case, we want to use the search results to then visit each individual page for each listing. Since we saved the links to the web pages in the previous scrape, we can now simply for-loop over that column in the dataframe, visiting the page listing for each of the cars in the search results:

# %% [markdown]
# # I moved the code to part 4.

# %%
# import time # Time delays
# import random # Random numbers

# links = df['link']
# data = []
# for link in links: # about 3 minutes
#     time.sleep(random.randint(1, 3)) # Random delays
#     raw = requests.get(link,headers=header) # Get page
#     bsObj = soup(raw.content,'html.parser') # Parse the html
#     #
#     try:
#         year_post = bsObj.find(class_='attr important').find(class_ = 'valu year').get_text()
#     except:
#         year_post = np.nan
#     #
#     try:
#         miles = bsObj.find(class_='attr auto_miles').find(class_ = 'valu').get_text()
#     except:
#         miles = np.nan
#     #
#     try:
#         color = bsObj.find(class_='attr auto_paint').find(href=True).get_text()
#     except:
#         color='missing'
#     #
#     try:
#         title = bsObj.find(class_='attr auto_title_status').find(href=True).get_text()
#     except:
#         title='missing'
#     #
#     try:
#         transmission = bsObj.find(class_='attr auto_transmission').find(href=True).get_text()
#     except:
#         transmission = 'missing'
#     #
#     try:
#         bodytype = bsObj.find(class_='attr auto_bodytype').find(href=True).get_text()
#     except:
#         bodytype = 'missing'
#     #
#     text = bsObj.find(id='postingbody').get_text()
#     text = text.replace('\n','')
#     text = text.replace('QR Code Link to This Post','')
#     record = {'title':title,
#               'year_post':year_post,
#               'miles':miles,
#               'color':color,
#               'title':'title',
#               'transmission':transmission,
#               'bodytype':bodytype,
#               'text':text,}
#     data.append(record)
# data

# %% [markdown]
# What are the new features here?
#
# First, we don't want to overwhelm the servers, so we put a small delay between each request of a listing, `time.sleep(random.randint(1, 3))`. This waits a random amount of time between 1 and 3 seconds to avoid overwhelming their server.
#
# Second, we use the try/except block. This is a useful control structure in general, but especially for web scraping. Python tries the statements under `try:`, and if it fails, executes the steps under `except:`. This can happen, in this case, with missing data, which crashes the crawler. Instead, we put our missing codes into our dataframe right away.
#
# Third, we used `.find().find().get_text()` to find the data we're looking for. In general, the structure of mark-up langauges like HTML and XML makes it possible to "drill down" into their entries and extract the information of interest. This exploitation of mark-up languages could be the subject of a whole course on procuring data from the web.

# %% [markdown]
# With the data scraped, we can make a new dataframe, combine it with the old one using `pd.concat`, and do some wrangling to clean the data up:

# %%
# import time # Time delays
# import random # Random numbers

# links = df['link']
# data = []
# for link in links: # about 3 minutes
#     time.sleep(random.randint(1, 3)) # Random delays
#     raw = requests.get(link,headers=header) # Get page
#     bsObj = soup(raw.content,'html.parser') # Parse the html
#     #
#     try:
#         year_post = bsObj.find(class_='attr important').find(class_ = 'valu year').get_text()
#     except:
#         year_post = np.nan
#     #
#     try:
#         condition = bsObj.find(class_='attr condition').find(href=True).get_text()
#     except:
#         condition = 'missing'
#     #
#     try:
#         cylinders = bsObj.find(class_='attr auto_cylinders').find(class_ = 'valu').get_text()
#         cylinders = cylinders.replace('\n','')
#     except:
#         cylinders = 'missing'
#     #
#     try:
#         drivetrain = bsObj.find(class_='attr auto_drivetrain').find(href=True).get_text()
#     except:
#         drivetrain = 'missing'
#     #
#     try:
#         fuel = bsObj.find(class_='attr auto_fuel_type').find(href = True).get_text()
#     except:
#         fuel = 'missing'
#     #
#     try:
#         miles = bsObj.find(class_='attr auto_miles').find(class_ = 'valu').get_text()
#     except:
#         miles = np.nan
#     #
#     try:
#         color = bsObj.find(class_='attr auto_paint').find(href=True).get_text()
#     except:
#         color='missing'
#     #
#     try:
#         title = bsObj.find(class_='attr auto_title_status').find(href=True).get_text()
#     except:
#         title='missing'
#     #
#     try:
#         transmission = bsObj.find(class_='attr auto_transmission').find(href=True).get_text()
#     except:
#         transmission = 'missing'
#     #
#     try:
#         bodytype = bsObj.find(class_='attr auto_bodytype').find(href=True).get_text()
#     except:
#         bodytype = 'missing'
#     #
#     text = bsObj.find(id='postingbody').get_text()
#     text = text.replace('\n','')
#     text = text.replace('QR Code Link to This Post','')
#     record = {'title':title,
#               'year_post':year_post,
#               'condition':condition,
#               'cylinders':cylinders,
#               'drivetrain':drivetrain,
#               'fuel':fuel,
#               'miles':miles,
#               'color':color,
#               'title':'title',
#               'transmission':transmission,
#               'bodytype':bodytype,
#               'text':text,}
#     data.append(record)
# data

# %%
# new_df = pd.DataFrame.from_dict(data)
# new_df.head()

# df = pd.concat([df,new_df],axis=1) # combine data frames
# df.head()

# # df['miles'] = df['miles'].str.replace(',','')
# df['miles'] = pd.to_numeric(df['miles'],errors='coerce')

# df['year_post'] = df['year_post'].str.replace(',','')
# df['year_post'] = pd.to_numeric(df['year_post'],errors='coerce')
# df.to_csv('craiglist_cville_cars_long.csv')

# %% [markdown]
# ## 4. From your search results, crawl to the links and extract more information about every listing in your original dataframe. Wrangle and do some EDA.

# %%
import time # Time delays
import random # Random numbers

links = df['link']
data = []
for link in links: # about 3 minutes
    time.sleep(random.randint(1, 3)) # Random delays
    raw = requests.get(link,headers=header) # Get page
    bsObj = soup(raw.content,'html.parser') # Parse the html
    #

    # Extracting the title
    try:
        title = bsObj.find(id='titletextonly').get_text()
    except:
        title = 'missing'

    # Extracting the price
    try:
        price = bsObj.find('span', class_='price').get_text()
    except:
        price = 'missing'

    # Extracting the year
    try:
        year = bsObj.find('span', class_='valu year').get_text()
    except:
        year = 'missing'

    # Extracting the engine displacement
    try:
        engine_displacement = bsObj.find('div', class_='attr engine_displacement_cc').find('span', class_='valu').get_text()
    except:
        engine_displacement = 'missing'

    # Extracting the mileage
    try:
        miles = bsObj.find('div', class_='attr auto_miles').find('span', class_='valu').get_text()
    except:
        miles = 'missing'

    # Extracting the title status
    try:
        title_status = bsObj.find('div', class_='attr auto_title_status').find('span', class_='valu').get_text()
    except:
        title_status = 'missing'

    # Extracting the transmission
    try:
        transmission = bsObj.find('div', class_='attr auto_transmission').find('span', class_='valu').get_text()
    except:
        transmission = 'missing'

    # Extracting the condition
    try:
        condition = bsObj.find('div', class_='attr condition').find('span', class_='valu').get_text()
    except:
        condition = 'missing'

    # Extracting the body type
    try:
        body_type = bsObj.find('div', class_='attr motorcycle_type').find('span', class_='valu').get_text()
    except:
        body_type = 'missing'

    # Extracting the posting description text
    try:
        description = bsObj.find(id='postingbody').get_text().strip().replace('QR Code Link to This Post', '').strip()
    except:
        description = 'missing'

    # Creating a record
    record = {
        'title': title,
        'price': price,
        'year': year,
        'engine_displacement': engine_displacement,
        'miles': miles,
        'title_status': title_status,
        'transmission': transmission,
        'condition': condition,
        'body_type': body_type,
        'description': description
    }

    data.append(record)
data
# Out:
# [{'title': '1991 Harley Heritage Softtail',
#   'price': '$5,300',
#   'year': '1991',
#   'engine_displacement': '1340',
#   'miles': '61,732',
#   'title_status': ' clean\n',
#   'transmission': ' manual\n',
#   'condition': ' excellent\n',
#   'body_type': ' cruiser\n',
#   'description': '1991 (never needs inspections) Harley Heritage Softtail.  Ready to ride.  Full service done last year.  Starts every time.  Owned by same family for 30 years.  It is a classic.  There is a dent in gas tank near the filler cap.  New front tire. New odometer. Have rear rider seat.  New windshield. Leather saddle bags.\n$5300 OBO !!!!\n\nSend phone number by Craig’s.  I’ll text.  Cuts down on scammers.\n\n. Moved to the trike family!!'},
#  {'title': '2003 SV650S Track Bike',
#   'price': '$1,500',
#   'year': '2003',
#   'engine_displacement': 'missing',
#   'miles': '9,255',
#   'title_status': 'missing',
#   'transmission': 'missing',
#   'condition': ' good\n',
#   'body_type': ' sport bike\n',
#   'description': 'I’m selling a track-only (no title, clean VIN) 2003 Suzuki SV650S with 9255 miles. I’d like to get $1500 for it.\n\nThis bike is 100% track-ready, which means there are no lights, no mirrors, no signals, no passenger footpegs, and no horn. I have some of these take-off parts if that’s important to you. I also installed frame sliders, swingarm spools, and lever guards. You can buy this bike and, five minutes later, pass tech and get on the track.\n\nI bought it last winter as a backup for the season and rode three track days with zero issues, including September 14th at NCBike. \n\nMechanically, the bike is solid with zero issues. Before this season, I replaced the tires (Michelin Power 6), chain and sprockets, brake pads (EBC HH), all fluids (fork oil, engine oil, brake fluid, coolant), filters (air and oil), grips, and front springs. I trust this bike more than a labrador to bring back a tennis ball.\n\nThe brakes, suspension, and engine are 100% OEM, except, as noted above, it has 0.90 springs for a 190 lb rider (although I identify as a 125 lb Japanese factory rider, so please respect that).\n\nCosmetically. Well, if you’ve made it this far I assume you didn’t look at the photos or don’t care about cosmetics. It’s not a good-looking bike. I’d rather watch my parents have sex. \n\nWhat I’m offering is a very affordable way to get on the track. It’s a great way to start, but even coaches and advanced riders still ride SVs. I’d never forgive myself if I wrecked my sweet-ass street bike on the track. But I don’t worry about this bike. It’s simple, easy to work on, and parts are cheap and everywhere. My local 7-11 sells 2nd gen. SV parts.'},
#  {'title': '2017 Indian Roadmaster',
#   'price': '$14,995',
#   'year': '',
#   'engine_displacement': '1811',
#   'miles': '25,300',
#   'title_status': 'missing',
#   'transmission': 'missing',
#   'condition': ' excellent\n',
#   'body_type': ' touring\n',
#   'description': 'Have a great day riding the roads this fall on this beautiful Indian Roadmaster! Am/Fm radio or Bluetooth your favorite music from your phone. Cruise, heated front and passenger seats, the lockable trunk and saddlebags provide lots of secure storage. This bike has the Stage One breather package with the large chrome air filter and real dual exhaust pipes. It had the Stage Two “ Cam” power package. And GPS as well. Good tires and in great condition with only 25,300 miles. All this for $14,995!!!'},
#  {'title': '2005 Yamaha V-Star',
#   'price': '$3,750',
#   'year': '2005',
#   'engine_displacement': '1100',
#   'miles': '8,933',
#   'title_status': 'missing',
#   'transmission': ' manual\n',
#   'condition': ' excellent\n',
#   'body_type': ' cruiser\n',
#   'description': 'Yamaha V-Star 1,100. New carbs, fuel flush, and oil change within last 3 months. Runs great. Garage kept.'},
#  {'title': '2021 KTM390 Adventure',
#   'price': '$5,500',
#   'year': '',
#   'engine_displacement': '390',
#   'miles': '7,900',
#   'title_status': ' clean\n',
#   'transmission': 'missing',
#   'condition': 'missing',
#   'body_type': ' adventure\n',
#   'description': '2021 KTM 390 Adventure\n7900 miles\nWe purchased brand new in 2021\nIt’s a great little bike!\nInstalled header pipe with cat delete \nFuel Tuner\nWith the exhaust and tuner it beat a DR650 in a drag race by quite a bit.\n1 inch lowering shock\nSkid plate\nHand guards\nOxford Heated grips\nDoubletake mirrors\nRear tail rack\nStock crash bars\nOil changed every 2500 miles\nKTM recommends every 4000\nLast oil change at 7600 miles\nBrand new rear tire mounted\nFront tire has plenty of tread\nI set the bike up for my wife and then daughter. \nSelling because daughter moved out of state.\nClear title in hand.\nCall or text me'},
#  {'title': '2017 Ducati Scrambler 800',
#   'price': '$6,500',
#   'year': '2017',
#   'engine_displacement': '800',
#   'miles': '1,215',
#   'title_status': ' clean\n',
#   'transmission': ' manual\n',
#   'condition': ' excellent\n',
#   'body_type': 'missing',
#   'description': "$6500 or best offer \n\nSelling my 2017 Ducati Scrambler 800 w/ 1215 miles...That's correct...1200 not 12,000.  Starts great.  Runs great.  Tires are good.  Brakes are good.  All stock...no aftermarket stuff and nothing has been tweaked.  Never dropped. Never raced.  Battery is new.  Oil changed a few weeks ago. Comes with saddle bags that came with it from the dealer.  Always kept under carport.\n\nTitle is in hand.  I purchased new from the dealer in Salem, Virginia. \n\nTest rides are welcome with cash in hand.\n\nBut wait...there's more.  Comes with...\n- Pit Bull trailer restraint system (new, in box)\n- Abba bike stand\n\nBuyer will need a method of transfer; however, I do have a VersaHaul single motorcycle carrier w/ ramp that I'd be willing to part with for a little extra.  The signal lights are busted on it though.\nI think it's this model:  https://www.versahaul.com/vh55ro.php"},
#  {'title': '2018 Vespa GTS Super ABS',
#   'price': '$4,750',
#   'year': '2018',
#   'engine_displacement': '300',
#   'miles': '2,330',
#   'title_status': ' clean\n',
#   'transmission': ' automatic\n',
#   'condition': ' like new\n',
#   'body_type': ' scooter/moped\n',
#   'description': '2018 Vespa GTS Super ABS\n\nOnly 2330 carefully driven miles.  $4750 or best offer.  This price has been reduced and is below national average for this scooter as advertised in such online publications as Facebook, Cycle Trader, and Modern Vespa.  Cash only, pick up in Charlottesville, VA, clear title, one owner.\n\nThis classic, but super modern Vespa is in perfect condition with careful use and regular attention from mature riders.  There is not a scratch, dent or mar on it (save for a small burn mark on the saddle from a fallen ember after a lightning strike).  It has never been dropped and has recently been checked by a scooter mechanic prior to placing it on sale. \n\nIt is only for sale because my wife and I, as seniors, are retiring from riding.  Also available are full face and open helmets, protective  clothing with Kevlar padding (best for highway driving) and a weather-proof scooter cover.\n\nAmong its very desirable options are a matching color OE Vespa back cargo box. an OE Vespa short windscreen, and OE Vespa protective bars around the (steel) body work.  In addition to the box, there is commodious storage under the saddle and there is hang hook for grocery bags.\n\nThe modern engine is 300 cc, with fuel injection and water cooling with a radiator.  Automatic belt-drive transmission.  ABS (anti lock braking system) is an important safety feature not often found on cycles, which greatly reduces risk of rear wheel lock up - a major cause of motorcycle accidents.  This Vespa easily reaches 80 MPH and I have driven it at pace with traffic on interstates, but do not advise it, as it is a small vehicle in the midst of large trucks, etc.  But it can go anywhere a car can go, without struggle.  There are many accounts of cross country rides with a scooter this capable.  It is quiet, stable and very smooth riding.  It is easy to maneuver and park - I have used it as my main in-town vehicle in all but the worst weather.\n\nHere are a couple of links with full specifications snd reviews from cycle publications:\n\nhttps://www.topspeed.com/motorcycles/motorcycle-reviews/vespa/2018-vespa-gts-super-300-gts-super-300-sport/\n\nhttps://www.motorcyclenews.com/bike-reviews/piaggio/vespa-gts300/2009/'},
#  {'title': '2016 Harley-Davidson Trike Freewheeler',
#   'price': '$21,500',
#   'year': '2016',
#   'engine_displacement': '103',
#   'miles': '10,700',
#   'title_status': ' clean\n',
#   'transmission': ' manual\n',
#   'condition': ' like new\n',
#   'body_type': ' trike\n',
#   'description': 'Reasonable offers will be taken into consideration.\n\nIf you see this ad, the bike is still available for purchase.\n\nFor your safety and convenience, please only use the provided phone number to communicate via call or text. \nThank you!\n\nI am selling a 2016 Harley Davidson Freewheeler (FLRT) with 10,700 miles on it. This motorcycle is finished in a vibrant Velocity Red Sunglo color. It is equipped with a powerful 1690cc (103") fuel-injected engine and a smooth 6-speed transmission. Additionally, it features starter-aided reverse and cruise control and comes with two keys.\n\nUpon close inspection, I couldn\'t find any scratches, dents, or dings on the surface. Both the chrome and aluminum components are in exceptionally good condition. The tires still have a fair amount of tread remaining on them.\n\nHere are the details about the bike\'s extras:\n\n- Vance & Hines muffler\n- Air cleaner\n- Sundowner seat\n- Chrome front axle bolt covers\n- Timer cover\n- Luggage rack\n- Engine guard\n- Willy G grips\n- Skeleton mirrors\n- Derby cover\n- Pinstriping\n- Driving lights\n- Chrome rear bumper\n- Backrest\n- Stage 1 KIT\n- Chrome Harley rims\n\nIt\'s important to note that all the chrome accessories are Willy G branded.'},
#  {'title': '2003 Harley FatBoy',
#   'price': '$6,500',
#   'year': '',
#   'engine_displacement': 'missing',
#   'miles': '17,500',
#   'title_status': 'missing',
#   'transmission': 'missing',
#   'condition': 'missing',
#   'body_type': ' cruiser\n',
#   'description': '2003 100th Anniversary Harley Davidson Fat Boy \n17,500 miles'},
#  {'title': '2011 BMW R1200RT with new tires',
#   'price': '$6,000',
#   'year': '',
#   'engine_displacement': 'missing',
#   'miles': '39,500',
#   'title_status': 'missing',
#   'transmission': 'missing',
#   'condition': 'missing',
#   'body_type': ' sport touring\n',
#   'description': "2011 BMW R1200RT with brand new Dunlop RoadSmart IV tires, 39,500 miles, excellent condition with many extras. Bike has ABS, cruise control, heated seats/grips, computer, all factory-scheduled maintenance up to date, maintenance records from new, new OEM battery last year, new factory fuel pump installed by local dealer under recall at 35,885 miles. \n\nExtras: two windshields (one factory and one larger V-Technik), bar-backs and foot-peg lowering kits, 2 Alaska Leather seat pads, Givi trunk large 56L with back-rest and top rack, Denali CanSmart system with fork-mounted DRL's and rear-mounted extra tail-lights with pulse feature, OEM saddle-bag liners, OEM tank bag, Touratech locking dash-mounted GPS holder for Garmin XT (GPS unit not included).\n\nBike is in excellent condition, runs perfectly and needs nothing.\n\nPrice: $6,000.00"},
#  {'title': '2003 BMW R1200CL',
#   'price': '$3,000',
#   'year': '2003',
#   'engine_displacement': '1200',
#   'miles': '33,000',
#   'title_status': ' clean\n',
#   'transmission': 'missing',
#   'condition': ' good\n',
#   'body_type': ' cruiser\n',
#   'description': 'Runs great\nLooks great \nRides great \nFeels great \n\nHeated Seats, grips.\nCD player\n3 gallon gas tank\nTONS of storage options (including a yeti-holding trailer for all your travel/camping needs)\n\nThe trailer has a removable handle that secures to the hitch so you can cart it around to your preferred spot and do day rides while camping. This outfit holds everything and the kitchen sink. Truly. Passenger has lots of room, sturdy pegs, and two spacious handles.'},
#  {'title': '2008 BMW R1200 - For Sale',
#   'price': '$5,750',
#   'year': '2008',
#   'engine_displacement': '1200',
#   'miles': '7,700',
#   'title_status': ' clean\n',
#   'transmission': ' manual\n',
#   'condition': ' excellent\n',
#   'body_type': ' sport touring\n',
#   'description': 'I am selling my motorcycle, a 2008 BMW R1200, right before the beautiful fall season. I\'d love to keep the bike so I can explore the mountains more, but I\'m leaving Charlottesville and it\'s time for someone else to make memories with her. \n\nThis motorcycle is:\n- Garage kept\n- Low mileage (7k miles)\n- Comes with original saddle bags and helmet case mount\n- After market exhaust\n- New mirror\'s\n- Two custom Corbyn seats. \n- Original windscreen, mirrors, and exhaust are also available\n\nOnly issues with it\'s age are things like the gas gauge being unreliable and the "service" icon needing a specific diagnostic tool model that I never bothered to get. \n\nI\'m hopeful that whoever takes it next will ride it more than I got to, but it\'s a hell of a bike and I\'m sure the next owner will love it. \n\nTitle is in hand, listing for sale at $5,750 OBO. \n\nLet me know if you are interested.'},
#  {'title': '2012 Suzuki Burgman 400',
#   'price': '$2,500',
#   'year': '2012',
#   'engine_displacement': '400',
#   'miles': '12,500',
#   'title_status': ' clean\n',
#   'transmission': ' automatic\n',
#   'condition': ' good\n',
#   'body_type': ' scooter/moped\n',
#   'description': '2012 Suzuki Burgman 400\n\nCurrently 12331 miles \n\n400 cc engine, CVT transmission, ABS braking system\n\nRuns well\n\nSome scuffs and scrapes typical for the age, but looks good overall\n\nI moved this Burgman here from New Mexico last year. I rode it around Charlottesville for a while, but then purchased a car, and have not been riding this much over the past few months. \n\nNeeds to be inspected, but should pass\n\nIncludes cover, several spare keys, and also extra synthetic oil and filters\n\nClean title\n\nCash only \n\nPlease email if interested'}]

# %%
new_df = pd.DataFrame.from_dict(data)
new_df.head()

df = pd.concat([df,new_df],axis=1) # combine data frames
df.head()

df['miles'] = df['miles'].astype(str).str.replace(',', '')
df['miles'] = pd.to_numeric(df['miles'], errors='coerce')

df['engine_displacement'] = pd.to_numeric(df['engine_displacement'],errors='coerce')


df.to_csv('craiglist_cville_cars_long.csv')

# %%
df['miles']
# Out:
# 1      9255.0
# 2     25300.0
# 3      8933.0
# 4      7900.0
# 5      1215.0
# 6      2330.0
# 7     10700.0
# 10    33000.0
# 11     7700.0
# 12    12500.0
# 13        NaN
# 14        NaN
# 15        NaN
# 0     61732.0
# 8     17500.0
# 9     39500.0
# Name: miles, dtype: float64

# %%
df['engine_displacement']
# Out:
# 1        NaN
# 2     1811.0
# 3     1100.0
# 4      390.0
# 5      800.0
# 6      300.0
# 7      103.0
# 10    1200.0
# 11    1200.0
# 12     400.0
# 13       NaN
# 14       NaN
# 15       NaN
# 0     1340.0
# 8        NaN
# 9        NaN
# Name: engine_displacement, dtype: float64
